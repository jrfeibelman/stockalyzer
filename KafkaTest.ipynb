# %%
from stockalyzer.data.data_manager import *
from stockalyzer.data.data_fetcher import TDDataFetcher, YFDataFetcher
from stockalyzer.strategy.ema_crossover import EMACrossoverStrategy
from stockalyzer.strategy.rsi_ema import RSIEMAStrategy
from stockalyzer.model.stock import Stock

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('mode.chained_assignment', 'raise')

# %%
tickers = ['AAPL','AMZN','MSFT']
start_time = datetime(2019, 6, 1)
debug = False

# Configure upstream data fetcher
# Yahoo finance
fetcher_yf = YFDataFetcher(tickers)

# TD Ameritrade
fetcher_td = TDDataFetcher(tickers)

# Initialize a StockDataManager to fetch data 
sm_td = StockDataManager.load_from_data_fetcher(fetcher_td, start_time, interval='1d',debug=debug)
sm_yf = StockDataManager.load_from_data_fetcher(fetcher_yf, start_time, interval='1d',debug=debug)

print("We can get the data for one specific ticker from the stock manager")
display(sm_td._data['AAPL'].head())
display(sm_yf._data['AAPL'].head())

display(sm_yf._data.head())
print("Or we can just get the all of the data the stock manager fetched")
display(sm_td._data.head())

print("We can get the fundamentals data and create stock objects")
fundamentals = fetcher_td.get_fundamentals()
display(fundamentals)
stocks = {t:Stock(t, fundamentals=fundamentals.loc[t], finviz=True) for t in sm_td.tickers}
      
print("We can get finviz data from stock fundamentals")
display(stocks["AAPL"].stats) 

print("We can get the latest news from finviz")
display(stocks["AAPL"].news) 

print("We can get the latest price targets from finviz")
display(stocks["AAPL"].ratings) 

print("We can get the latest insider trades from finviz")
display(stocks["AAPL"].insider_trades)
# Out:
# /Users/jfeibs/Desktop/stockalyzer/stockalyzer/scripts/config/python/config.ini
# [*********************100%***********************]  3 of 3 completed
# We can get the data for one specific ticker from the stock manager
#                High        Low     Open    Close     Volume
# Date
# 2019-06-03  44.4800  42.567500  43.9000  43.3250  161584276
# 2019-06-04  44.9575  43.630000  43.8600  44.9100  123871844
# 2019-06-05  46.2475  45.285000  46.0700  45.6350  119093708
# 2019-06-06  46.3675  45.537225  45.7700  46.3050   90105244
# 2019-06-07  47.9800  46.442500  46.6275  47.5375  122737572
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-06-03  43.900002  44.480000  42.567501  43.325001  42.285892  161584400
# 2019-06-04  43.860001  44.957500  43.630001  44.910000  43.832882  123872000
# 2019-06-05  46.070000  46.247501  45.285000  45.634998  44.540485  119093600
# 2019-06-06  45.770000  46.367500  45.537498  46.305000  45.194424   90105200
# 2019-06-07  46.627499  47.980000  46.442501  47.537498  46.397366  122737600
#                    AMZN                                                      \
#                    Open         High          Low        Close    Adj Close
# Date
# 2019-06-03  1760.010010  1766.290039  1672.000000  1692.689941  1692.689941
# 2019-06-04  1699.239990  1730.819946  1680.890015  1729.560059  1729.560059
# 2019-06-05  1749.599976  1752.000000  1715.250000  1738.500000  1738.500000
# 2019-06-06  1737.709961  1760.000000  1726.130005  1754.359985  1754.359985
# 2019-06-07  1763.699951  1806.250000  1759.489990  1804.030029  1804.030029
#
#                            MSFT                                      \
#              Volume        Open        High         Low       Close
# Date
# 2019-06-03  9098700  123.849998  124.370003  119.010002  119.839996
# 2019-06-04  5679100  121.279999  123.279999  120.650002  123.160004
# 2019-06-05  4239800  124.949997  125.870003  124.209999  125.830002
# 2019-06-06  3689300  126.440002  127.970001  125.599998  127.820000
# 2019-06-07  4808200  129.190002  132.250000  128.259995  131.399994
#
#                                        AAPL                                   \
#              Adj Close    Volume       Open       High        Low      Close
# Date
# 2019-06-03  116.569214  37983600  43.900002  44.480000  42.567501  43.325001
# 2019-06-04  119.798607  29382600  43.860001  44.957500  43.630001  44.910000
# 2019-06-05  122.395752  24926100  46.070000  46.247501  45.285000  45.634998
# 2019-06-06  124.331413  21459000  45.770000  46.367500  45.537498  46.305000
# 2019-06-07  127.813721  33885600  46.627499  47.980000  46.442501  47.537498
#
#
#             Adj Close     Volume
# Date
# 2019-06-03  42.285892  161584400
# 2019-06-04  43.832882  123872000
# 2019-06-05  44.540485  119093600
# 2019-06-06  45.194424   90105200
# 2019-06-07  46.397366  122737600
# Or we can just get the all of the data the stock manager fetched
#                AAPL                                               AMZN  \
#                High        Low     Open    Close     Volume       High
# Date
# 2019-06-03  44.4800  42.567500  43.9000  43.3250  161584276  1766.2900
# 2019-06-04  44.9575  43.630000  43.8600  44.9100  123871844  1730.8200
# 2019-06-05  46.2475  45.285000  46.0700  45.6350  119093708  1752.0000
# 2019-06-06  46.3675  45.537225  45.7700  46.3050   90105244  1760.0000
# 2019-06-07  47.9800  46.442500  46.6275  47.5375  122737572  1806.2538
#
#                                                     MSFT                    \
#                   Low     Open    Close   Volume    High       Low    Open
# Date
# 2019-06-03  1672.0000  1760.01  1692.69  9098708  124.37  119.0100  123.85
# 2019-06-04  1680.8900  1699.24  1729.56  5679121  123.28  120.6522  121.28
# 2019-06-05  1715.2514  1749.60  1738.50  4239782  125.87  124.2100  124.95
# 2019-06-06  1726.1300  1737.71  1754.36  3689272  127.97  125.6000  126.44
# 2019-06-07  1759.4900  1763.70  1804.03  4808246  132.25  128.2600  129.19
#
#
#              Close    Volume
# Date
# 2019-06-03  119.84  37983637
# 2019-06-04  123.16  29382642
# 2019-06-05  125.83  24926140
# 2019-06-06  127.82  21458961
# 2019-06-07  131.40  33885588
# We can get the fundamentals data and create stock objects
#           cusip symbol                           description exchange  \
# MSFT  594918104   MSFT  Microsoft Corporation - Common Stock   NASDAQ
# AAPL  037833100   AAPL             Apple Inc. - Common Stock   NASDAQ
# AMZN  023135106   AMZN       Amazon.com, Inc. - Common Stock   NASDAQ
#
#      assetType    high52    low52  dividendAmount  dividendYield  \
# MSFT    EQUITY   349.670   238.07            2.48           0.94
# AAPL    EQUITY   182.940   122.25            0.92           0.61
# AMZN    EQUITY  3773.078  2159.14            0.00           0.00
#
#                  dividendDate   peRatio  pegRatio   pbRatio   prRatio  \
# MSFT  2022-05-18 00:00:00.000  27.60395  0.906705  12.15200  10.27645
# AAPL  2022-05-06 00:00:00.000  24.71668  0.649588  36.56616   6.37567
# AMZN                           52.60720  0.000000   8.26465   2.31684
#
#       pcfRatio  grossMarginTTM  grossMarginMRQ  netProfitMarginTTM  \
# MSFT  22.93440        68.73030        68.36507            37.62834
# AAPL  21.74325        43.32219        43.74987            26.40687
# AMZN  19.36058        42.13686        42.89186             4.48040
#
#       netProfitMarginMRQ  operatingMarginTTM  operatingMarginMRQ  \
# MSFT            33.88979            42.52819            41.15478
# AAPL            25.70982            30.92584            30.81786
# AMZN             0.00000             4.11995             3.15087
#
#       returnOnEquity  returnOnAssets  returnOnInvestment  quickRatio  \
# MSFT        48.72154        22.17523            28.76071     1.94509
# AAPL       149.27110        29.64002            44.91251     0.88402
# AMZN        18.04560         5.83366             8.93864     0.70884
#
#       currentRatio  interestCoverage  totalDebtToCapital  ltDebtToEquity  \
# MSFT       1.98765         180.21240            28.35010        37.88760
# AAPL       0.92684           0.00000            64.03085       153.30050
# AMZN       0.95963           0.42688            34.74189        51.07499
#
#       totalDebtToEquity    epsTTM  epsChangePercentTTM  epsChangeYear  \
# MSFT           39.56753   9.58486             30.44424        9.12750
# AAPL          178.01600   6.15212             38.04979        9.23257
# AMZN           53.23766  41.35898              0.00000        0.00000
#
#       epsChange  revChangeYear  revChangeTTM  revChangeIn  sharesOutstanding  \
# MSFT        0.0            0.0      20.37145          0.0       7.479033e+09
# AAPL        0.0            0.0      18.62627          0.0       1.618518e+10
# AMZN        0.0            0.0      13.98564          0.0       5.087205e+08
#
#       marketCapFloat  marketCap  bookValuePerShare  shortIntToFloat  \
# MSFT       7456.5900  1978803.0           15.41530              0.0
# AAPL      16173.6200  2461119.0            0.00000              0.0
# AMZN        458.4668  1106864.0           46.36798              0.0
#
#       shortIntDayToCover  divGrowthRate3Year  dividendPayAmount  \
# MSFT                 0.0                 0.0               0.62
# AAPL                 0.0                 0.0               0.23
# AMZN                 0.0                 0.0               0.00
#
#               dividendPayDate     beta   vol1DayAvg  vol10DayAvg  vol3MonthAvg
# MSFT  2022-06-09 00:00:00.000  0.94591   40421230.0   40421232.0  6.992193e+08
# AAPL  2022-05-12 00:00:00.000  1.19758  114415690.0  114415693.0  1.925425e+09
# AMZN                           1.26089    6371440.0    6371437.0  7.985238e+07
# We can get finviz data from stock fundamentals
# {'Company': 'Apple Inc.',
#  'Sector': 'Technology',
#  'Industry': 'Consumer Electronics',
#  'Country': 'USA',
#  'Index': 'DJIA S&P500',
#  'P/E': '25.12',
#  'EPS (ttm)': '6.15',
#  'Insider Own': '0.07%',
#  'Shs Outstand': '16.28B',
#  'Perf Week': '-3.12%',
#  'Market Cap': '2492.66B',
#  'Forward P/E': '23.58',
#  'EPS next Y': '6.62%',
#  'Insider Trans': '-1.75%',
#  'Shs Float': '16.17B',
#  'Perf Month': '-9.16%',
#  'Income': '101.94B',
#  'PEG': '2.53',
#  'EPS next Q': '1.16',
#  'Inst Own': '59.70%',
#  'Short Float': '0.64%',
#  'Perf Quarter': '-11.62%',
#  'Sales': '386.02B',
#  'P/S': '6.46',
#  'EPS this Y': '71.40%',
#  'Inst Trans': '-0.29%',
#  'Short Ratio': '1.12',
#  'Perf Half Y': '2.71%',
#  'Book/sh': '4.14',
#  'P/B': '37.32',
#  'ROA': '28.90%',
#  'Target Price': '190.20',
#  'Perf Year': '22.71%',
#  'Cash/sh': '3.19',
#  'P/C': '48.39',
#  'EPS next 5Y': '9.91%',
#  'ROE': '152.90%',
#  '52W Range': '122.25 - 182.94',
#  'Perf YTD': '-12.99%',
#  'Dividend': '0.92',
#  'P/FCF': '27.37',
#  'EPS past 5Y': '22.00%',
#  'ROI': '50.00%',
#  '52W High': '-15.54%',
#  'Beta': '1.20',
#  'Dividend %': '0.60%',
#  'Quick Ratio': '0.90',
#  'Sales past 5Y': '11.10%',
#  'Gross Margin': '43.30%',
#  '52W Low': '26.39%',
#  'ATR': '5.45',
#  'Employees': '154000',
#  'Current Ratio': '0.90',
#  'Sales Q/Q': '8.60%',
#  'Oper. Margin': '30.90%',
#  'RSI (14)': '41.06',
#  'Volatility': '3.84% 3.21%',
#  'Optionable': 'Yes',
#  'Debt/Eq': '1.78',
#  'EPS Q/Q': '9.20%',
#  'Profit Margin': '26.40%',
#  'Rel Volume': '1.25',
#  'Prev Close': '152.06',
#  'Shortable': 'Yes',
#  'LT Debt/Eq': '1.53',
#  'Earnings': 'Apr 28 AMC',
#  'Payout': '14.20%',
#  'Avg Volume': '92.30M',
#  'Price': '154.51',
#  'Recom': '1.90',
#  'SMA20': '-4.74%',
#  'SMA50': '-6.39%',
#  'SMA200': '-3.23%',
#  'Volume': '115,117,363',
#  'Change': '1.61%'}
# We can get the latest news from finviz
# [('Dow Jones Futures: Techs Rise In Volatile Stock Market Action; Has Inflation Fever Peaked?',
#   'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-techs-rise-in-volatile-stock-market-action-has-inflation-fever-peaked/?src=A00220'),
#  ('Early Money: A newly unveiled startup is helping scientists clean up artificial intelligence data',
#   'https://www.bizjournals.com/sanjose/inno/stories/fundings/2022/05/10/early-money-new-startup-works-to-clean-up-ml-data.html?ana=yahoo'),
#  ('Stocks end the day mixed, tech and energy sectors among biggest leaders',
#   'https://finance.yahoo.com/video/stocks-end-day-mixed-tech-200653786.html'),
#  ('RIP iPod: People pay tribute to Apples portable music player being discontinued',
#   'https://www.marketwatch.com/story/rip-ipod-people-pay-tribute-to-apples-portable-music-player-being-discontinued-11652210199?siteid=yhoof2'),
#  ('How CEO pay compares to median salaries at Apple, Facebook, Walmart and more',
#   'https://www.bizjournals.com/bizjournals/news/2022/05/10/ceo-pay-salary-for-americas-largest-companies.html?ana=yahoo'),
#  ('How Citizens Financial used an iPhone plan to create a nationwide digital bank',
#   'https://www.marketwatch.com/story/how-citizens-financial-used-an-iphone-plan-to-create-a-nationwide-digital-bank-11652207686?siteid=yhoof2'),
#  ('Apple Kills the Last Model of Its Iconic Music Player',
#   'https://www.barrons.com/articles/apple-kills-last-model-ipod-51652206068?siteid=yhoof2'),
#  ('The iPod is dead as Touch is finally discontinued, Apple says',
#   'https://finance.yahoo.com/news/ipod-dead-touch-finally-discontinued-165623911.html'),
#  ('Apple Officially Kills Off the iPod, More Than 20 Years After Music Player Debuted',
#   'https://finance.yahoo.com/news/apple-officially-kills-off-ipod-170219183.html'),
#  ('Antitrust Chief Barred From Google Cases Amid Recusal Push',
#   'https://finance.yahoo.com/news/antitrust-chief-barred-google-cases-120010512.html'),
#  ('End of an Era: Apple\xa0Discontinues Its Last\xa0iPod Model',
#   'https://finance.yahoo.com/news/end-era-apple-discontinues-last-162851661.html'),
#  ('Dow falls, Tesla stock reverses gains, SoFi stock halted on early earnings release',
#   'https://finance.yahoo.com/video/dow-falls-tesla-stock-reverses-160451422.html'),
#  ('Top Millennial, Gen Z Stock Picks Shift To Energy Stocks; But Tesla Still No. 1',
#   'https://www.investors.com/news/top-millennial-and-gen-z-stock-picks-from-tesla-to-apple-should-you-buy-them-too/?src=A00220'),
#  ('Market check: Oil falls, tech stocks post modest gains',
#   'https://finance.yahoo.com/video/market-check-oil-falls-tech-152601640.html'),
#  ('10 Most Popular Mutual Funds on Reddit',
#   'https://finance.yahoo.com/news/10-most-popular-mutual-funds-145135978.html'),
#  ("Warren Buffett Stocks: What's Inside Berkshire Hathaway's Portfolio?",
#   'https://www.investors.com/research/warren-buffett-stocks/?src=A00220'),
#  ('Market Crash: Monster Growth Stocks to Buy Right Away',
#   'https://www.fool.com/investing/2022/05/10/market-crash-monster-growth-stocks-to-buy-right-aw/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('Stocks rise, oil steadies, BlackRock cuts rating on China assets',
#   'https://finance.yahoo.com/video/stocks-rise-oil-steadies-blackrock-142321214.html'),
#  ('10 Tech Stocks to Buy Now According to Barry Dargans Intermede Investment Partners',
#   'https://finance.yahoo.com/news/10-tech-stocks-buy-now-140534392.html'),
#  ('Tech stocks lose over $1 trillion in value over 3 days',
#   'https://finance.yahoo.com/video/tech-stocks-lose-over-1-132958166.html'),
#  ('Apple, Netflix, and Other Tech Stocks Are Crumbling. The Pain Might Not Be Over.',
#   'https://www.barrons.com/articles/faang-apple-amazon-alphabet-stocks-losses-earnings-outlook-51652130116?siteid=yhoof2'),
#  ('Match sues Google after being refused the same app-store treatment as Spotify',
#   'https://www.marketwatch.com/story/match-sues-google-after-being-refused-the-same-app-store-treatment-as-spotify-11652135260?siteid=yhoof2'),
#  ("3 Tech Stocks Investors Shouldn't Lose Sleep Over",
#   'https://finance.yahoo.com/news/3-tech-stocks-investors-shouldnt-220110833.html'),
#  ("Games Giant's Pitch for Global Talent: Embrace Your Inner Geek",
#   'https://finance.yahoo.com/news/china-other-gaming-giant-quietly-220000879.html'),
#  ('How Apple Stock Could Save the S&P 500 From a Bear Market',
#   'https://www.barrons.com/articles/sp500-bear-market-apple-51652120401?siteid=yhoof2'),
#  ('Apple and Amazon Have Fallen for 6 Straight Weeks. There Could Be More Pain Ahead.',
#   'https://www.barrons.com/articles/apple-amazon-stock-tech-losing-streaks-51652112126?siteid=yhoof2'),
#  ('Dow sinks over 600 points into the close, S&P 500 closes at lowest level in more than a year',
#   'https://finance.yahoo.com/video/dow-sinks-over-600-points-201609337.html'),
#  ('Billionaire Ken Fishers 10 Favorite Tech Stocks',
#   'https://finance.yahoo.com/news/billionaire-ken-fisher-10-favorite-174522134.html'),
#  ("Is Apple Stock A Buy Or Sell After iPhone Maker's Earnings Report?",
#   'https://www.investors.com/research/apple-stock-buy-now/?src=A00220'),
#  ('Alphabet (GOOGL) Boosts YouTube Music With Latest Effort',
#   'https://finance.yahoo.com/news/alphabet-googl-boosts-youtube-music-183306400.html'),
#  ('Apple Faces EU Antitrust Action on Apple Pay',
#   'https://www.investopedia.com/apple-faces-eu-antitrust-action-on-apple-pay-5271156?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral'),
#  ('Apple and Amazon Have Fallen for 6 Straight Weeks. There Could Be More Pain Ahead.',
#   'https://www.barrons.com/articles/apple-aapl-amazon-amzn-losing-streaks-51652112126?siteid=yhoof2'),
#  ('Tech stock headwinds leading to more downside for the Nasdaq: Strategist',
#   'https://finance.yahoo.com/video/tech-stock-headwinds-leading-more-152450210.html'),
#  ('Why Apple Stock Got Bit on Monday',
#   'https://www.fool.com/investing/2022/05/09/why-apple-stock-got-bit-on-monday/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('Stocks: S&P 500 touches 52-week low, Microsoft market cap dips below $2 trillion',
#   'https://finance.yahoo.com/video/stocks-p-500-touches-52-151627552.html'),
#  ('Market check: Dow falls 500+ points, bitcoin sells off',
#   'https://finance.yahoo.com/video/market-check-dow-falls-500-145739931.html'),
#  ('Megacap Optimists Buckle Under Weight of Bear Market',
#   'https://finance.yahoo.com/news/megacap-optimists-buckle-under-weight-105154336.html'),
#  ('Tech Sell-Off: 1 Growth Stock Down 73% to Buy Right Now',
#   'https://www.fool.com/investing/2022/05/09/tech-sell-off-1-growth-stock-down-73-buy-right-now/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('5G Stocks To Buy And Watch: Will Dish Entry Shake-Up 5G Market?',
#   'https://www.investors.com/news/technology/5g-stocks-5g-wireless-stocks/?src=A00220'),
#  ('Better Buffett Stock: Chevron vs. Apple',
#   'https://www.fool.com/investing/2022/05/09/better-buffett-stock-chevron-vs-apple/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ("Dow Jones Futures Tumble As Market Correction Extends Losses; Why Apple Is An 'Absolute Loser'",
#   'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-market-correction-extends-sell-off-why-apple-stock-is-an-absolute-loser/?src=A00220'),
#  ('Aramco Closes In on Apple as Worlds Most Valuable Firm',
#   'https://finance.yahoo.com/news/aramco-closes-apple-world-most-113947433.html'),
#  ('Can Samsungs Galaxy smart tag plus key tracker rival Apple and Tile?',
#   'https://finance.yahoo.com/news/samsung-galaxy-smart-tag-plus-113411260.html'),
#  ('Apple exec quits over working from home row',
#   'https://finance.yahoo.com/news/apple-exec-quits-over-working-105031927.html'),
#  ('Videos of People Dragged Into Quarantine Censored in China',
#   'https://finance.yahoo.com/news/videos-people-dragged-quarantine-censored-055400471.html'),
#  ('3 Top Stocks to Buy in May',
#   'https://www.fool.com/investing/2022/05/09/3-top-stocks-to-buy-in-may/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('Stocks Extend Slump, Week Ahead, Uber, Apple, Twitter In Focus - Five Things You Must Know',
#   'https://www.thestreet.com/markets/-5-things-you-must-know-before-market-opens-monday-050922?puc=yahoo&cm_ven=YAHOO'),
#  ('Chinas Export Growth Weakens to 2020 Low as Lockdowns Bite',
#   'https://finance.yahoo.com/news/china-export-growth-weakens-2020-040853530.html'),
#  ("Apple's Services Business Has Never Been More Important",
#   'https://www.fool.com/investing/2022/05/08/apples-services-business-has-never-been-more-impor/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('What Pushed Apple Factory Workers to Riot?',
#   'https://www.thestreet.com/investing/why-apple-workers-rioted?puc=yahoo&cm_ven=YAHOO'),
#  ('Its Not Just Tesla. 8 Other Stocks to Play the Future of Transportation.',
#   'https://www.barrons.com/articles/the-future-of-transportation-is-a-lot-more-than-tesla-how-to-invest-51651871098?siteid=yhoof2'),
#  ('First U.S. Apple store union election is set for early June',
#   'https://finance.yahoo.com/news/first-us-apple-store-union-election-is-set-for-early-june-143517263.html'),
#  ('2 Top Buffett Stocks to Buy and Hold for the Long Haul',
#   'https://www.fool.com/investing/2022/05/07/2-top-buffett-stocks-buy-and-hold-for-long-haul/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('2 Top 5G Stocks to Buy in May',
#   'https://www.fool.com/investing/2022/05/07/2-top-5g-stocks-to-buy-in-may/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ("Why a Successful Microsoft Is Good for All Investors -- Even If They Don't Own the Stock",
#   'https://www.fool.com/investing/2022/05/07/why-a-successful-microsoft-is-good-for-all-investo/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('If Roe v. Wade is overturned, what happens to housing markets in states with trigger laws that would immediately ban abortion?',
#   'https://www.marketwatch.com/story/if-roe-v-wade-was-overturned-what-happens-to-real-estate-markets-in-states-with-trigger-laws-that-would-immediately-ban-abortion-in-those-states-11651850682?siteid=yhoof2'),
#  ('Ken Fisher is Selling These 10 Stocks in 2022',
#   'https://finance.yahoo.com/news/ken-fisher-selling-10-stocks-205550096.html'),
#  ('Roe v. Wade: How corporate America has responded to the Supreme Court draft opinion',
#   'https://finance.yahoo.com/video/roe-v-wade-corporate-america-203857546.html'),
#  ('The market is basically forecasting stagflation: Strategist',
#   'https://finance.yahoo.com/video/market-basically-forecasting-stagflation-strategist-193554845.html'),
#  ('Amazon is Offering a Rare Sale on Apple AirTags, iPhone Cases and Chargers',
#   'https://www.thestreet.com/personal-finance/amazon-apple-accessories-airtag-sale?puc=yahoo&cm_ven=YAHOO'),
#  ('Chaos Erupts At Apple Plant In China Due To Strict Lockdown',
#   'https://finance.yahoo.com/news/chaos-erupts-apple-plant-china-164654077.html'),
#  ("The most expensive TV shows of all time: 'Stranger Things' and 'Lord of the Rings' enter pantheon",
#   'https://finance.yahoo.com/news/the-most-expensive-tv-shows-of-all-time-stranger-things-and-lord-of-the-rings-enter-pantheon-152120290.html'),
#  ('Top Funds Bet On These Stocks To Rise From Down Market',
#   'https://www.investors.com/etfs-and-funds/mutual-funds/best-mutual-funds-buy-aapl-brkb-pm-stock-in-market-correction-as-new-uptrend-awaits/?src=A00220'),
#  ('Tony Fadell created the iPod and co-created the iPhone. He almost didnt join Apple',
#   'https://finance.yahoo.com/news/tony-fadell-created-the-i-pod-and-co-created-the-i-phone-he-almost-didnt-join-apple-142945922.html'),
#  ('10 Companies that Just Increased Their Dividends',
#   'https://finance.yahoo.com/news/10-companies-just-increased-dividends-133338921.html'),
#  ('Dow Jones Futures Fall After Stocks Plunge, Treasury Yields Soar In Delayed Fed Reaction',
#   'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-nasdaq-dives-to-new-lows-as-treasury-yields-soar-in-delayed-fed-reaction/?src=A00220'),
#  ('Digital markets regulation: Big Tech means big problems',
#   'https://www.ft.com/cms/s/81ec4b69-5866-4b53-9142-4a8ae9b812e5,s01=1.html?ftcamp=traffic/partner/feed_headline/us_yahoo/auddev'),
#  ('Should You Buy Apple Stock Right Now?',
#   'https://www.fool.com/investing/2022/05/06/should-you-buy-apple-stock-right-now/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ("Mega Caps Struggle, Becky Quick on Berkshire-Hathaway's Future",
#   'https://www.fool.com/investing/2022/05/06/mega-caps-struggle-becky-quick-on-berkshire-hathaw/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('Workers at Apple China Plant Clash With Guards Over Lockdowns',
#   'https://finance.yahoo.com/news/workers-apple-china-plant-clash-093257967.html'),
#  ("73% of Warren Buffett's Portfolio Is Invested in These 5 Stocks",
#   'https://www.fool.com/investing/2022/05/06/73-warren-buffetts-portfolio-invested-in-5-stocks/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('Higher Inflation,\xa0Rates Will Stick Around as Economies Go Green',
#   'https://finance.yahoo.com/news/higher-inflation-rates-stick-around-050002606.html'),
#  ('Apple pours millions into Oaklands CNote platform to support minority-owned businesses',
#   'https://www.bizjournals.com/sanfrancisco/news/2022/05/05/apple-pours-millions-into-oakland-s-cnote-platform.html?ana=yahoo'),
#  ('Microsoft is using Fortnite to fuel its cloud gaming growth',
#   'https://qz.com/2162540/fortnite-gamers-dont-need-to-wait-for-apple-microsoft-is-here/?utm_source=YPL'),
#  ('Tesla, Amazon, Alibaba among biggest market laggards of the day',
#   'https://finance.yahoo.com/video/tesla-amazon-alibaba-among-biggest-194513840.html'),
#  ('Why Apple, Meta Platforms, and Salesforce.com Plunged Today',
#   'https://www.fool.com/investing/2022/05/05/why-apple-meta-platforms-and-salesforcecom-plunged/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('Dow Jones Plunges; Tesla Dives On This Elon Musk Twitter Move; Apple Stock Falls As Tech Tumbles',
#   'https://www.investors.com/market-trend/stock-market-today/dow-jones-plunges-tesla-stock-dives-on-this-elon-musk-twitter-move-apple-stock-microsoft-stock-fall-as-tech-tumbles/?src=A00220'),
#  ('Market check: Stock sell-off accelerates as traders weigh Fed policy',
#   'https://finance.yahoo.com/video/market-check-stock-sell-off-161443699.html'),
#  ('Apple, Google and Microsoft take major step to get rid of passwords',
#   'https://finance.yahoo.com/news/apple-google-microsoft-major-step-152521898.html'),
#  ('Stock market: Dow falls 900+ points, Nikola shares rise',
#   'https://finance.yahoo.com/video/e-commerce-stocks-plunge-earnings-152136642.html'),
#  ('Apple, Google and Microsoft agree to support passwordless sign-ins',
#   'https://finance.yahoo.com/news/apple-google-microsoft-agree-support-151828700.html'),
#  ('Apple has spent decades building its walled garden. It may be starting to crack',
#   'https://www.marketwatch.com/story/apple-has-spent-decades-building-its-walled-garden-it-may-be-starting-to-crack-11651762698?siteid=yhoof2'),
#  ('Supply-Chain Woes Hitting Apple for Billions',
#   'https://www.fool.com/investing/2022/05/05/supply-chain-woes-hitting-apple-for-billions/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('Best Oversold Stocks to Buy Now for May 2022',
#   'https://finance.yahoo.com/news/best-oversold-stocks-buy-now-140315705.html'),
#  ('Forget your passwords, the era of facial recognition and fingerprints is finally here',
#   'https://finance.yahoo.com/news/apple-google-microsoft-expand-thumb-132716070.html'),
#  ('Brad Gerstner is Talking About These 10 Stocks',
#   'https://finance.yahoo.com/news/brad-gerstner-talking-10-stocks-131440293.html'),
#  ("Dow Jones Futures Fall After Fed's Powell Fuels Big Market Rally; Apple, Exxon Flash Buy Signals",
#   'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-stocks-soar-as-powell-rules-out-even-bigger-fed-rate-hikes-apple-exxon-flash-buy-signals/?src=A00220'),
#  ("Only 1 Smartphone Brand Grew Sales Last Quarter (and It's No Surprise)",
#   'https://www.fool.com/investing/2022/05/05/only-1-smartphone-brand-grew-sales-q1-apple/?source=eptyholnk0000202&utm_source=yahoo-host&utm_medium=feed&utm_campaign=article'),
#  ('Your investments and why its right to diversify',
#   'https://www.ft.com/cms/s/c8536e2c-4ff6-44e5-9c46-c9d573b4537b,s01=1.html?ftcamp=traffic/partner/feed_headline/us_yahoo/auddev'),
#  ('Why Star Wars Day is the most successful fake holiday',
#   'https://qz.com/2162154/why-star-wars-day-is-the-most-successful-fake-holiday/?utm_source=YPL'),
#  ('Streaming wars: How much money each company spends on content',
#   'https://finance.yahoo.com/video/streaming-wars-much-money-company-205844986.html'),
#  ("This 'rater' gets paid $10 an hour to teach Google's algorithm  and he's not alone",
#   'https://finance.yahoo.com/news/google-raters-paid-to-teach-algorithm-204308901.html'),
#  ("Dow Jones Jumps As Powell Soothes These Fears; Bill Gates Says Elon Musk Could Make Twitter 'Worse'",
#   'https://www.investors.com/market-trend/stock-market-today/dow-jones-jumps-as-jerome-powell-soothes-interest-rate-fears-bill-gates-says-elon-musk-could-make-twitter-worse/?src=A00220'),
#  ('Powell Gives Tech a Lift by Taking Larger Hikes off the Table',
#   'https://finance.yahoo.com/news/powell-gives-tech-lift-taking-194325831.html'),
#  ('Stocks hit session highs into the close, FAANG stocks jump',
#   'https://finance.yahoo.com/video/stocks-hit-session-highs-close-200733602.html'),
#  ('Apple Stock Holds Up Fairly Well; Could This Bull Put Spread Generate A 262% Annualized Gain?',
#   'https://www.investors.com/research/options/apple-stock-holds-up-fairly-well-could-this-bull-put-spread-generate-a-262-percent-annualized-gain/?src=A00220'),
#  ('Stocks: Nasdaq flat, S&P 500 and Dow higher following Fed rate hike announcement',
#   'https://finance.yahoo.com/video/stocks-nasdaq-flat-p-500-183535531.html'),
#  ('PODCAST: Which Documents to Keep, Which to Shred and Which to Scan',
#   'https://finance.yahoo.com/news/podcast-documents-keep-shred-scan-183143944.html'),
#  ('Investing in Apple Stock (AAPL)',
#   'https://www.investopedia.com/apple-stock-aapl-5075819?utm_campaign=quote-yahoo&utm_source=yahoo&utm_medium=referral'),
#  ("ETF Areas in the Spotlight Post Buffett's 2022 Meeting",
#   'https://finance.yahoo.com/news/etf-areas-spotlight-post-buffetts-181306811.html')]
# We can get the latest price targets from finviz
# [{'date': 'Apr-19-22',
#   'category': 'Initiated',
#   'analyst': 'Rosenblatt',
#   'rating': 'Neutral',
#   'price_from': '2022-04-19',
#   'price_to': 'Initiated'},
#  {'date': 'Jan-28-22',
#   'category': 'Upgrade',
#   'analyst': 'New Street',
#   'rating': 'Sell → Neutral',
#   'price_from': '2022-01-28',
#   'price_to': 'Upgrade'},
#  {'date': 'Jan-28-22',
#   'category': 'Reiterated',
#   'analyst': 'Monness Crespi & Hardt',
#   'rating': 'Buy',
#   'price_from': '2022-01-28',
#   'price_to': 'Reiterated'},
#  {'date': 'Dec-14-21',
#   'category': 'Upgrade',
#   'analyst': 'BofA Securities',
#   'rating': 'Neutral → Buy',
#   'price_from': '2021-12-14',
#   'price_to': 'Upgrade'},
#  {'date': 'Dec-13-21',
#   'category': 'Reiterated',
#   'analyst': 'JP Morgan',
#   'rating': 'Overweight',
#   'price_from': '2021-12-13',
#   'price_to': 'Reiterated'},
#  {'date': 'Dec-07-21',
#   'category': 'Reiterated',
#   'analyst': 'Morgan Stanley',
#   'rating': 'Overweight',
#   'price_from': '2021-12-07',
#   'price_to': 'Reiterated'},
#  {'date': 'Dec-06-21',
#   'category': 'Initiated',
#   'analyst': 'KeyBanc Capital Markets',
#   'rating': 'Overweight',
#   'price_from': '2021-12-06',
#   'price_to': 'Initiated'},
#  {'date': 'Oct-29-21',
#   'category': 'Resumed',
#   'analyst': 'Credit Suisse',
#   'rating': 'Neutral',
#   'price_from': '2021-10-29',
#   'price_to': 'Resumed'}]
# We can get the latest insider trades from finviz
# [{'Insider Trading': 'Adams Katherine L.',
#   'Relationship': 'SVP, GC and Secretary',
#   'Date': 'May 04',
#   'Transaction': 'Sale',
#   'Cost': '161.72',
#   '#Shares': '25,000',
#   'Value ($)': '4,042,888',
#   '#Shares Total': '452,334',
#   'SEC Form 4': 'May 06 06:30 PM'},
#  {'Insider Trading': "O'BRIEN DEIRDRE",
#   'Relationship': 'Senior Vice President',
#   'Date': 'Apr 18',
#   'Transaction': 'Sale',
#   'Cost': '164.91',
#   '#Shares': '8,000',
#   'Value ($)': '1,319,305',
#   '#Shares Total': '136,290',
#   'SEC Form 4': 'Apr 19 06:31 PM'},
#  {'Insider Trading': 'WILLIAMS JEFFREY E',
#   'Relationship': 'COO',
#   'Date': 'Apr 04',
#   'Transaction': 'Sale',
#   'Cost': '177.75',
#   '#Shares': '105,901',
#   'Value ($)': '18,824,389',
#   '#Shares Total': '489,662',
#   'SEC Form 4': 'Apr 05 06:33 PM'},
#  {'Insider Trading': "O'BRIEN DEIRDRE",
#   'Relationship': 'Senior Vice President',
#   'Date': 'Apr 04',
#   'Transaction': 'Sale',
#   'Cost': '177.77',
#   '#Shares': '29,198',
#   'Value ($)': '5,190,427',
#   '#Shares Total': '136,290',
#   'SEC Form 4': 'Apr 05 06:32 PM'},
#  {'Insider Trading': 'Adams Katherine L.',
#   'Relationship': 'SVP, GC and Secretary',
#   'Date': 'Feb 03',
#   'Transaction': 'Sale',
#   'Cost': '174.78',
#   '#Shares': '25,000',
#   'Value ($)': '4,369,548',
#   '#Shares Total': '419,715',
#   'SEC Form 4': 'Feb 07 06:30 PM'},
#  {'Insider Trading': 'LEVINSON ARTHUR D',
#   'Relationship': 'Director',
#   'Date': 'Feb 01',
#   'Transaction': 'Sale',
#   'Cost': '173.29',
#   '#Shares': '1,986',
#   'Value ($)': '344,154',
#   '#Shares Total': '4,532,724',
#   'SEC Form 4': 'Feb 03 06:35 PM'},
#  {'Insider Trading': 'KONDO CHRIS',
#   'Relationship': 'Principal Accounting Officer',
#   'Date': 'Nov 12',
#   'Transaction': 'Sale',
#   'Cost': '150.00',
#   '#Shares': '9,005',
#   'Value ($)': '1,350,750',
#   '#Shares Total': '37,197',
#   'SEC Form 4': 'Nov 16 06:30 PM'},
#  {'Insider Trading': 'Adams Katherine L.',
#   'Relationship': 'SVP, GC and Secretary',
#   'Date': 'Nov 01',
#   'Transaction': 'Sale',
#   'Cost': '148.68',
#   '#Shares': '25,000',
#   'Value ($)': '3,716,895',
#   '#Shares Total': '447,993',
#   'SEC Form 4': 'Nov 03 06:31 PM'},
#  {'Insider Trading': 'Maestri Luca',
#   'Relationship': 'Senior Vice President, CFO',
#   'Date': 'Oct 19',
#   'Transaction': 'Sale',
#   'Cost': '148.62',
#   '#Shares': '165,829',
#   'Value ($)': '24,645,506',
#   '#Shares Total': '110,501',
#   'SEC Form 4': 'Oct 21 06:30 PM'},
#  {'Insider Trading': "O'BRIEN DEIRDRE",
#   'Relationship': 'Senior Vice President',
#   'Date': 'Oct 18',
#   'Transaction': 'Sale',
#   'Cost': '146.35',
#   '#Shares': '18,247',
#   'Value ($)': '2,670,391',
#   '#Shares Total': '136,118',
#   'SEC Form 4': 'Oct 19 06:31 PM'},
#  {'Insider Trading': 'WILLIAMS JEFFREY E',
#   'Relationship': 'COO',
#   'Date': 'Oct 04',
#   'Transaction': 'Sale',
#   'Cost': '138.83',
#   '#Shares': '165,829',
#   'Value ($)': '23,022,040',
#   '#Shares Total': '489,490',
#   'SEC Form 4': 'Oct 05 06:44 PM'},
#  {'Insider Trading': "O'BRIEN DEIRDRE",
#   'Relationship': 'Senior Vice President',
#   'Date': 'Oct 04',
#   'Transaction': 'Sale',
#   'Cost': '138.83',
#   '#Shares': '89,437',
#   'Value ($)': '12,416,539',
#   '#Shares Total': '136,118',
#   'SEC Form 4': 'Oct 05 06:43 PM'},
#  {'Insider Trading': 'COOK TIMOTHY D',
#   'Relationship': 'Chief Executive Officer',
#   'Date': 'Aug 25',
#   'Transaction': 'Sale',
#   'Cost': '148.58',
#   '#Shares': '2,386,440',
#   'Value ($)': '354,568,479',
#   '#Shares Total': '3,279,726',
#   'SEC Form 4': 'Aug 26 06:30 PM'},
#  {'Insider Trading': "O'BRIEN DEIRDRE",
#   'Relationship': 'Senior Vice President',
#   'Date': 'Aug 06',
#   'Transaction': 'Sale',
#   'Cost': '145.99',
#   '#Shares': '14,877',
#   'Value ($)': '2,171,893',
#   '#Shares Total': '136,118',
#   'SEC Form 4': 'Aug 09 06:30 PM'},
#  {'Insider Trading': 'Adams Katherine L.',
#   'Relationship': 'SVP, GC and Secretary',
#   'Date': 'Aug 02',
#   'Transaction': 'Sale',
#   'Cost': '145.89',
#   '#Shares': '17,000',
#   'Value ($)': '2,480,048',
#   '#Shares Total': '307,164',
#   'SEC Form 4': 'Aug 04 06:30 PM'}]

# %%
# TODO learn about urox networking communication w timer & ulltra
# Create reference data --> security definitions, instrument / fundamentals definitions, previous prices, previous statsbook
# Create event drive MD price feed for getting live data updates
# C++ doe ...
        # Need to figure out how to pass timer context for tcp conns in c++ ?????
    
    
# APP: Need to make a python app for pulling reference data and publishing to kafka

# %%
# import yfinance as yf
# tickers = ['AAPL']

# data = yf.Ticker("AAPL")

# display(data.info)
# display(data.splits)
# display(data.actions)
# display(data.history(period='max'))
# display(data.dividends)


# # show financials
# data.financials
# data.quarterly_financials

# # show major holders
# data.major_holders

# # show institutional holders
# data.institutional_holders

# # show balance sheet
# data.balance_sheet
# data.quarterly_balance_sheet

# # show cashflow
# data.cashflow
# data.quarterly_cashflow

# # show earnings
# data.earnings
# data.quarterly_earnings

# # show sustainability
# data.sustainability

# # show analysts recommendations
# data.recommendations

# # show next event (earnings, etc)
# data.calendar

# # show ISIN code - *experimental*
# # ISIN = International Securities Identification Number
# data.isin

# # show options expirations
# data.options

# # show news
# data.news

# # get option chain for specific expiration
# # opt = data.option_chain('YYYY-MM-DD')
# # data available via: opt.calls, opt.puts

# %%
# from kafka import KafkaProducer, KafkaConsumer
# from configparser import RawConfigParser
# from json import dumps, loads
# import os

# config = RawConfigParser()
# config_path = "%s/../config/python/config.ini" % os.getcwd()
# config.read(config_path)

# host = config.get('Kafka', 'host')
# print(host)
# producer = KafkaProducer(bootstrap_servers=[host],
#                          api_version=(3,1,0),
#                          value_serializer=lambda x: 
#                          dumps(x).encode('utf-8'))
# consumer = KafkaConsumer(
#     'test-kafka',
#      bootstrap_servers=[host],
#      api_version=(3,1,0),
#      auto_offset_reset='earliest',
#      enable_auto_commit=True,
#      group_id='my-group',
#      value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
from kafka import KafkaProducer, KafkaConsumer
from configparser import RawConfigParser
from json import dumps, loads
import os

class KafkaTester:
    def __init__(self, config_path, topic):
        config = RawConfigParser()
        config.read(config_path)
        self.host = config.get('Kafka', 'host')
        
    # TODO pass list of topics and make a dict topic:consumer
    
    def consume(self, topic, consumer=None):
        if None is consumer:
            consumer = KafkaConsumer(
                 topic,
                 bootstrap_servers=[self.host],
                 api_version=(3,1,0),
                 auto_offset_reset='earliest',
                 enable_auto_commit=True,
                 group_id='my-group',
                 value_deserializer=lambda x: loads(x.decode('utf-8')))
        
        for message in consumer:
            message = message.value
            print('found {}'.format(message))
        
        return consumer
        
    def produce(self, topic, data, producer=None):
        if None is producer:
            producer = KafkaProducer(bootstrap_servers=[host],
                             api_version=(3,1,0),
                             value_serializer=lambda x: 
                             dumps(x).encode('utf-8'))

        producer.send(topic, value=data)
        
        return producer

# %%
topic = 'test-kafka'
config = RawConfigParser()
config_path = "%s/../config/python/config.ini" % os.getcwd()
config.read(config_path)

host = config.get('Kafka', 'host')
print(config_path)


ktester = KafkaTester(config_path, topic)
ktester.produce(topic, "TESTING")
ktester.consume(topic)
# Out:
# ['/Users/jfeibs/Desktop/stockalyzer/stockalyzer/scripts/../config/python/config.ini']
# /Users/jfeibs/Desktop/stockalyzer/stockalyzer/scripts/../config/python/config.ini
# found TESTING

# %%
class KafkaProducer:
    def __init__(self, host, topic):
        self.host = host
        self.topic
        
        self.producer = KafkaProducer(bootstrap_servers=[host],
                     api_version=(3,1,0),
                     value_serializer=lambda x: 
                     dumps(x).encode('utf-8'))
        
    def send(self, data):
        producer.send(self.topic, value=data)

# %%
class 

class ReferenceDataManager:
